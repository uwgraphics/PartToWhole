# %%
# Import libraries
library(ggplot2)
library(dplyr)
library(ggdist)
library(patchwork)

# %%
# Load data
allConditions <- read.csv("data/allConditions.csv", header=T)
allConditions
# Out:
#      selectedPart alignmentCategory anchorCategory anchorDistance
# 1    15           aligned           far-anchor     10
# 2    15           near-aligned      far-anchor     10
# 3    15           near-aligned      far-anchor     10
# 4    15           near-aligned      far-anchor     10
# 5    15           near-aligned      far-anchor     10
# 6    15           far-from-aligned  far-anchor     10
# 7    15           near-aligned      far-anchor     10
# 8    15           near-aligned      far-anchor     10
# 9    15           near-aligned      far-anchor     10
# 10   15           near-aligned      far-anchor     10
# 11   15           aligned           far-anchor     10
# 12   15           far-from-aligned  far-anchor     10
# 13   15           far-from-aligned  far-anchor     10
# 14   15           far-from-aligned  far-anchor     10
# 15   15           far-from-aligned  far-anchor     10
# 16   15           far-from-aligned  far-anchor     10
# 17   15           far-from-aligned  far-anchor     10
# 18   15           near-aligned      far-anchor     10
# 19   15           near-aligned      far-anchor     10
# 20   15           near-aligned      far-anchor     10
# 21   15           near-aligned      far-anchor     10
# 22   15           aligned           far-anchor     10
# 23   15           far-from-aligned  far-anchor     10
# 24   15           near-aligned      far-anchor     10
# 25   15           near-aligned      far-anchor     10
# 26   15           near-aligned      far-anchor     10
# 27   15           near-aligned      far-anchor     10
# 28   15           aligned           far-anchor     10
# 29   15           far-from-aligned  far-anchor     10
# 30   15           far-from-aligned  far-anchor     10
# ⋮    ⋮            ⋮                 ⋮              ⋮
# 2273 55           far-from-aligned  far-anchor     5
# 2274 55           far-from-aligned  far-anchor     5
# 2275 55           far-from-aligned  far-anchor     5
# 2276 55           far-from-aligned  far-anchor     5
# 2277 55           near-aligned      far-anchor     5
# 2278 55           near-aligned      far-anchor     5
# 2279 55           near-aligned      far-anchor     5
# 2280 55           near-aligned      far-anchor     5
# 2281 55           aligned           far-anchor     5
# 2282 55           near-aligned      far-anchor     5
# 2283 55           near-aligned      far-anchor     5
# 2284 55           aligned           far-anchor     5
# 2285 55           near-aligned      far-anchor     5
# 2286 55           near-aligned      far-anchor     5
# 2287 55           far-from-aligned  far-anchor     5
# 2288 55           far-from-aligned  far-anchor     5
# 2289 55           far-from-aligned  far-anchor     5
# 2290 55           far-from-aligned  far-anchor     5
# 2291 55           far-from-aligned  far-anchor     5
# 2292 55           far-from-aligned  far-anchor     5
# 2293 55           far-from-aligned  far-anchor     5
# 2294 55           far-from-aligned  far-anchor     5
# 2295 55           far-from-aligned  far-anchor     5
# 2296 55           far-from-aligned  far-anchor     5
# 2297 55           far-from-aligned  far-anchor     5
# 2298 55           near-aligned      far-anchor     5
# 2299 55           near-aligned      far-anchor     5
# 2300 55           near-aligned      far-anchor     5
# 2301 55           near-aligned      far-anchor     5
# 2302 55           aligned           far-anchor     5
#      alignmentDistance round5Distance alignmentType alignmentPosition
# 1    0                 0              0              0
# 2    1                 0              0              1
# 3    2                 0              0              2
# 4    3                 0              0              3
# 5    4                 0              0              4
# 6    5                 0              0 and 25       5
# 7    4                 0              25             6
# 8    3                 0              25             7
# 9    2                 0              25             8
# 10   1                 0              25             9
# 11   0                 0              25            10
# 12   5                 0              25            15
# 13   6                 0              25            16
# 14   7                 0              25            17
# 15   7                 0              25            18
# 16   6                 0              25            19
# 17   5                 0              25            20
# 18   4                 0              25            21
# 19   3                 0              25            22
# 20   2                 0              25            23
# 21   1                 0              25            24
# 22   0                 0              25            25
# 23   5                 0              25 and 50     30
# 24   4                 0              50            31
# 25   3                 0              50            32
# 26   2                 0              50            33
# 27   1                 0              50            34
# 28   0                 0              50            35
# 29   5                 0              50            40
# 30   6                 0              50            41
# ⋮    ⋮                 ⋮              ⋮             ⋮
# 2273  8                0              75            12
# 2274  7                0              75            13
# 2275  6                0              75            14
# 2276  5                0              75            15
# 2277  4                0              75            16
# 2278  3                0              75            17
# 2279  2                0              75            18
# 2280  1                0              75            19
# 2281  0                0              75            20
# 2282  2                0              25            23
# 2283  1                0              25            24
# 2284  0                0              25            25
# 2285  3                0              25            28
# 2286  4                0              25            29
# 2287  5                0              25            30
# 2288  6                0              25            31
# 2289  7                0              25            32
# 2290  8                0              25            33
# 2291  9                0              25            34
# 2292 10                0              25 and 100    35
# 2293  9                0              100           36
# 2294  8                0              100           37
# 2295  7                0              100           38
# 2296  6                0              100           39
# 2297  5                0              100           40
# 2298  4                0              100           41
# 2299  3                0              100           42
# 2300  2                0              100           43
# 2301  1                0              100           44
# 2302  0                0              100           45

# %%
library(dplyr)

participantIDs <- 1:100

# Define anchor categories and alignment categories
anchorCategories <- c("anchor", "near-anchor", "far-anchor")
alignmentCategories <- c("aligned", "near-aligned", "far-from-aligned")
chartTypes <- c("line", "pie")

# Sampling targets per anchor category
anchorCounts <- list(
  anchor = 12, 
  `near-anchor` = 36,
  `far-anchor` = 48
)

set.seed(123)
participantStimuli <- list()

for (pid in participantIDs) {
  participantDF <- data.frame()

  for (anchor in anchorCategories) {
    total <- anchorCounts[[anchor]]
    per_chart <- total / 2  # per chartType

    # Temporary variables for easier reference
    n_aligned <- ceiling(per_chart * 0.25)
    n_remaining <- per_chart - n_aligned
    n_near <- floor(n_remaining / 2)
    n_far <- per_chart - n_aligned - n_near

    alignmentCounts <- c(
      aligned = n_aligned,
      `near-aligned` = n_near,
      `far-from-aligned` = n_far
    )

    for (chart in chartTypes) {
      for (align in names(alignmentCounts)) {
        n_to_sample <- alignmentCounts[[align]]

        if (anchor == "anchor") {
          # Split n_to_sample evenly between anchorValue 25 and 50
          n_each_anchor <- floor(n_to_sample / 2)
          leftover <- n_to_sample - 2 * n_each_anchor  # In case of odd number

          for (anchorValue in c(25, 50)) {
            give_extra_to_25 <- (pid %% 2 == 1)
            n_this <- n_each_anchor + ifelse((anchorValue == 25) == give_extra_to_25, leftover, 0)

            sample_pool <- allConditions %>%
              filter(anchorCategory == anchor,
                     alignmentCategory == align,
                     anchorValue == anchorValue)

            if (nrow(sample_pool) < n_this) {
              warning(paste("Not enough samples for:", anchor, align, chart, anchorValue))
            }

            sampled <- sample_pool %>%
              sample_n(n_this, replace = TRUE) %>%
              mutate(chartType = chart)

            participantDF <- bind_rows(participantDF, sampled)
          }

        } else {
          sample_pool <- allConditions %>%
            filter(anchorCategory == anchor,
                   alignmentCategory == align)

          if (nrow(sample_pool) < n_to_sample) {
            warning(paste("Not enough samples for:", anchor, align, chart))
          }

          sampled <- sample_pool %>%
            sample_n(n_to_sample, replace = TRUE) %>%
            mutate(chartType = chart)

          participantDF <- bind_rows(participantDF, sampled)
        }
      }
    }
  }

  participantDF$UID <- pid
  participantStimuli[[pid]] <- participantDF
}

stimuli <- bind_rows(participantStimuli)
stimuli$selectedLabel <- sample(LETTERS[1:7], nrow(stimuli), replace = TRUE)
stimuli
# Out:
#      selectedPart alignmentCategory anchorCategory anchorDistance
# 1    50           aligned           anchor         0
# 2    50           aligned           anchor         0
# 3    50           near-aligned      anchor         0
# 4    25           near-aligned      anchor         0
# 5    25           far-from-aligned  anchor         0
# 6    50           far-from-aligned  anchor         0
# 7    25           aligned           anchor         0
# 8    50           aligned           anchor         0
# 9    25           near-aligned      anchor         0
# 10   25           near-aligned      anchor         0
# 11   50           far-from-aligned  anchor         0
# 12   25           far-from-aligned  anchor         0
# 13   24           aligned           near-anchor    1
# 14   48           aligned           near-anchor    2
# 15   46           aligned           near-anchor    4
# 16   22           aligned           near-anchor    3
# 17   48           aligned           near-anchor    2
# 18   21           near-aligned      near-anchor    4
# 19   21           near-aligned      near-anchor    4
# 20   27           near-aligned      near-anchor    2
# 21   48           near-aligned      near-anchor    2
# 22   46           near-aligned      near-anchor    4
# 23   23           near-aligned      near-anchor    2
# 24   23           far-from-aligned  near-anchor    2
# 25   22           far-from-aligned  near-anchor    3
# 26   47           far-from-aligned  near-anchor    3
# 27   47           far-from-aligned  near-anchor    3
# 28   46           far-from-aligned  near-anchor    4
# 29   24           far-from-aligned  near-anchor    1
# 30   21           far-from-aligned  near-anchor    4
# ⋮    ⋮            ⋮                 ⋮              ⋮
# 9571 54           far-from-aligned  far-anchor      4
# 9572 52           far-from-aligned  far-anchor      2
# 9573 20           far-from-aligned  far-anchor      5
# 9574 53           far-from-aligned  far-anchor      3
# 9575 39           far-from-aligned  far-anchor     11
# 9576 18           far-from-aligned  far-anchor      7
# 9577 45           aligned           far-anchor      5
# 9578 36           aligned           far-anchor     11
# 9579 35           aligned           far-anchor     10
# 9580 18           aligned           far-anchor      7
# 9581 16           aligned           far-anchor      9
# 9582 37           aligned           far-anchor     12
# 9583 40           near-aligned      far-anchor     10
# 9584 37           near-aligned      far-anchor     12
# 9585 33           near-aligned      far-anchor      8
# 9586 40           near-aligned      far-anchor     10
# 9587 31           near-aligned      far-anchor      6
# 9588 45           near-aligned      far-anchor      5
# 9589 36           near-aligned      far-anchor     11
# 9590 19           near-aligned      far-anchor      6
# 9591 44           near-aligned      far-anchor      6
# 9592 37           far-from-aligned  far-anchor     12
# 9593 37           far-from-aligned  far-anchor     12
# 9594 53           far-from-aligned  far-anchor      3
# 9595 51           far-from-aligned  far-anchor      1
# 9596 53           far-from-aligned  far-anchor      3
# 9597 51           far-from-aligned  far-anchor      1
# 9598 43           far-from-aligned  far-anchor      7
# 9599 55           far-from-aligned  far-anchor      5
# 9600 55           far-from-aligned  far-anchor      5
#      alignmentDistance round5Distance alignmentType alignmentPosition chartType
# 1     0                0              50 and 100    50                line
# 2     0                0              50 and 100    50                line
# 3     3                0              0 and 50       3                line
# 4     3                0              75 and 100    72                line
# 5     7                0              0 and 25       7                line
# 6    11                0              25 and 75     14                line
# 7     0                0              25 and 50     25                pie
# 8     0                0              25 and 75     25                pie
# 9     2                0              50 and 75     48                pie
# 10    4                0              25 and 50     21                pie
# 11    9                0              50 and 100    41                pie
# 12    7                0              25 and 50     18                pie
# 13    0                1              0              0                line
# 14    0                2              0              0                line
# 15    0                1              0              0                line
# 16    0                2              0              0                line
# 17    0                2              75            27                line
# 18    3                1              75            72                line
# 19    4                1              25            21                line
# 20    4                2              50            19                line
# 21    3                2              25            22                line
# 22    1                1              50             3                line
# 23    3                2              75            55                line
# 24   10                2              25            12                line
# 25   11                2              25 and 25     14                line
# 26    7                2              25            18                line
# 27    6                2              50            44                line
# 28    9                1              25            16                line
# 29    9                1              50            41                line
# 30    9                1              75            66                line
# ⋮    ⋮                 ⋮              ⋮             ⋮                 ⋮
# 9571  6                1              25            31                line
# 9572 11                2              0             11                line
# 9573  6                0              50            36                line
# 9574 10                2              100           37                line
# 9575  7                1              50 and 75     43                line
# 9576  8                2              75            65                line
# 9577  0                0              0              0                pie
# 9578  0                1              100           64                pie
# 9579  0                0              25            25                pie
# 9580  0                2              50            32                pie
# 9581  0                1              75            59                pie
# 9582  0                2              0              0                pie
# 9583  3                0              50             7                pie
# 9584  4                2              100           59                pie
# 9585  4                2              25            29                pie
# 9586  3                0              50             7                pie
# 9587  3                1              50            53                pie
# 9588  2                0              25            23                pie
# 9589  3                1              50            47                pie
# 9590  4                1              25            21                pie
# 9591  3                1              75            34                pie
# 9592  6                2              50            56                pie
# 9593  5                2              50            45                pie
# 9594  6                2              25            31                pie
# 9595  6                1              100           43                pie
# 9596  8                2              0              8                pie
# 9597  9                1              75            15                pie
# 9598  6                2              50            44                pie
# 9599  6                0              100           39                pie
# 9600  5                0              75            15                pie
#      UID selectedLabel
# 1    1   B
# 2    1   G
# 3    1   C
# 4    1   D
# 5    1   D
# 6    1   C
# 7    1   D
# 8    1   D
# 9    1   E
# 10   1   F
# 11   1   D
# 12   1   F
# 13   1   B
# 14   1   C
# 15   1   F
# 16   1   F
# 17   1   F
# 18   1   A
# 19   1   G
# 20   1   C
# 21   1   F
# 22   1   F
# 23   1   C
# 24   1   A
# 25   1   B
# 26   1   B
# 27   1   B
# 28   1   C
# 29   1   C
# 30   1   B
# ⋮    ⋮   ⋮
# 9571 100 E
# 9572 100 D
# 9573 100 E
# 9574 100 D
# 9575 100 A
# 9576 100 G
# 9577 100 B
# 9578 100 B
# 9579 100 E
# 9580 100 F
# 9581 100 F
# 9582 100 F
# 9583 100 A
# 9584 100 F
# 9585 100 B
# 9586 100 F
# 9587 100 A
# 9588 100 B
# 9589 100 D
# 9590 100 F
# 9591 100 B
# 9592 100 F
# 9593 100 F
# 9594 100 A
# 9595 100 G
# 9596 100 C
# 9597 100 E
# 9598 100 E
# 9599 100 D
# 9600 100 C

# %%
set.seed(123)
labels <- LETTERS[1:7]  # A to G

set.seed(123)
labels <- LETTERS[1:7]  # A to G

# Helper to get 'n' positive integers summing to 'target'
sample_partition <- function(n, target) {
  repeat {
    raw <- rbeta(n, 2, 10)
    scaled <- round(raw / sum(raw) * target)
    diff <- target - sum(scaled)
    if (diff != 0) scaled[1] <- scaled[1] + diff
    if (all(scaled > 0)) return(scaled)
  }
}

generate_parts_row <- function(row) {
  selectedPart <- as.numeric(row[["selectedPart"]])
  selectedLabel <- as.character(row[["selectedLabel"]])
  alignmentPos <- as.numeric(row[["alignmentPosition"]])

  otherLabels <- setdiff(labels, selectedLabel)
  remainingSpace <- 100 - selectedPart
  leftSpace <- alignmentPos
  rightSpace <- 100 - selectedPart - alignmentPos

  # Determine how many go left vs right
  leftCount <- round(6 * (leftSpace / (leftSpace + rightSpace)))
  rightCount <- 6 - leftCount

  # Adjust for edge cases
  if (leftCount == 0 && leftSpace > 0) {
    leftCount <- 1
    rightCount <- 5
  }
  if (rightCount == 0 && rightSpace > 0) {
    rightCount <- 1
    leftCount <- 5
  }

  # Sample values for each side
  leftVals <- if (leftCount > 0) sample_partition(leftCount, leftSpace) else numeric(0)
  rightVals <- if (rightCount > 0) sample_partition(rightCount, rightSpace) else numeric(0)

  # Combine full part values in left → selected → right order
  partValues <- c(leftVals, selectedPart, rightVals)

  # Assign labels and indices
  shuffledLabels <- sample(otherLabels)
  leftLabels <- if (leftCount > 0) shuffledLabels[1:leftCount] else character(0)
  rightLabels <- if (rightCount > 0) shuffledLabels[(leftCount + 1):(leftCount + rightCount)] else character(0)
  orderedLabels <- c(leftLabels, selectedLabel, rightLabels)

  values <- setNames(rep(NA_integer_, 7), labels)
  indexMap <- setNames(rep(NA_integer_, 7), paste0(labels, "_ind"))

  for (i in 0:6) {
    lab <- orderedLabels[i + 1]
    values[lab] <- partValues[i + 1]
    indexMap[paste0(lab, "_ind")] <- i
  }

  return(as.list(c(values, indexMap)))
}

newParts <- lapply(1:nrow(stimuli), function(i) generate_parts_row(stimuli[i, ]))
newParts_df <- as.data.frame(do.call(rbind, newParts), stringsAsFactors = FALSE)

for (col in c(LETTERS[1:7], paste0(LETTERS[1:7], "_ind"))) {
  newParts_df[[col]] <- as.numeric(newParts_df[[col]])
}

stimuli <- cbind(stimuli, newParts_df)
stimuli
# Out:
#      selectedPart alignmentCategory anchorCategory anchorDistance
# 1    50           aligned           anchor         0
# 2    50           aligned           anchor         0
# 3    50           near-aligned      anchor         0
# 4    25           near-aligned      anchor         0
# 5    25           far-from-aligned  anchor         0
# 6    50           far-from-aligned  anchor         0
# 7    25           aligned           anchor         0
# 8    50           aligned           anchor         0
# 9    25           near-aligned      anchor         0
# 10   25           near-aligned      anchor         0
# 11   50           far-from-aligned  anchor         0
# 12   25           far-from-aligned  anchor         0
# 13   24           aligned           near-anchor    1
# 14   48           aligned           near-anchor    2
# 15   46           aligned           near-anchor    4
# 16   22           aligned           near-anchor    3
# 17   48           aligned           near-anchor    2
# 18   21           near-aligned      near-anchor    4
# 19   21           near-aligned      near-anchor    4
# 20   27           near-aligned      near-anchor    2
# 21   48           near-aligned      near-anchor    2
# 22   46           near-aligned      near-anchor    4
# 23   23           near-aligned      near-anchor    2
# 24   23           far-from-aligned  near-anchor    2
# 25   22           far-from-aligned  near-anchor    3
# 26   47           far-from-aligned  near-anchor    3
# 27   47           far-from-aligned  near-anchor    3
# 28   46           far-from-aligned  near-anchor    4
# 29   24           far-from-aligned  near-anchor    1
# 30   21           far-from-aligned  near-anchor    4
# ⋮    ⋮            ⋮                 ⋮              ⋮
# 9571 54           far-from-aligned  far-anchor      4
# 9572 52           far-from-aligned  far-anchor      2
# 9573 20           far-from-aligned  far-anchor      5
# 9574 53           far-from-aligned  far-anchor      3
# 9575 39           far-from-aligned  far-anchor     11
# 9576 18           far-from-aligned  far-anchor      7
# 9577 45           aligned           far-anchor      5
# 9578 36           aligned           far-anchor     11
# 9579 35           aligned           far-anchor     10
# 9580 18           aligned           far-anchor      7
# 9581 16           aligned           far-anchor      9
# 9582 37           aligned           far-anchor     12
# 9583 40           near-aligned      far-anchor     10
# 9584 37           near-aligned      far-anchor     12
# 9585 33           near-aligned      far-anchor      8
# 9586 40           near-aligned      far-anchor     10
# 9587 31           near-aligned      far-anchor      6
# 9588 45           near-aligned      far-anchor      5
# 9589 36           near-aligned      far-anchor     11
# 9590 19           near-aligned      far-anchor      6
# 9591 44           near-aligned      far-anchor      6
# 9592 37           far-from-aligned  far-anchor     12
# 9593 37           far-from-aligned  far-anchor     12
# 9594 53           far-from-aligned  far-anchor      3
# 9595 51           far-from-aligned  far-anchor      1
# 9596 53           far-from-aligned  far-anchor      3
# 9597 51           far-from-aligned  far-anchor      1
# 9598 43           far-from-aligned  far-anchor      7
# 9599 55           far-from-aligned  far-anchor      5
# 9600 55           far-from-aligned  far-anchor      5
#      alignmentDistance round5Distance alignmentType alignmentPosition chartType
# 1     0                0              50 and 100    50                line
# 2     0                0              50 and 100    50                line
# 3     3                0              0 and 50       3                line
# 4     3                0              75 and 100    72                line
# 5     7                0              0 and 25       7                line
# 6    11                0              25 and 75     14                line
# 7     0                0              25 and 50     25                pie
# 8     0                0              25 and 75     25                pie
# 9     2                0              50 and 75     48                pie
# 10    4                0              25 and 50     21                pie
# 11    9                0              50 and 100    41                pie
# 12    7                0              25 and 50     18                pie
# 13    0                1              0              0                line
# 14    0                2              0              0                line
# 15    0                1              0              0                line
# 16    0                2              0              0                line
# 17    0                2              75            27                line
# 18    3                1              75            72                line
# 19    4                1              25            21                line
# 20    4                2              50            19                line
# 21    3                2              25            22                line
# 22    1                1              50             3                line
# 23    3                2              75            55                line
# 24   10                2              25            12                line
# 25   11                2              25 and 25     14                line
# 26    7                2              25            18                line
# 27    6                2              50            44                line
# 28    9                1              25            16                line
# 29    9                1              50            41                line
# 30    9                1              75            66                line
# ⋮    ⋮                 ⋮              ⋮             ⋮                 ⋮
# 9571  6                1              25            31                line
# 9572 11                2              0             11                line
# 9573  6                0              50            36                line
# 9574 10                2              100           37                line
# 9575  7                1              50 and 75     43                line
# 9576  8                2              75            65                line
# 9577  0                0              0              0                pie
# 9578  0                1              100           64                pie
# 9579  0                0              25            25                pie
# 9580  0                2              50            32                pie
# 9581  0                1              75            59                pie
# 9582  0                2              0              0                pie
# 9583  3                0              50             7                pie
# 9584  4                2              100           59                pie
# 9585  4                2              25            29                pie
# 9586  3                0              50             7                pie
# 9587  3                1              50            53                pie
# 9588  2                0              25            23                pie
# 9589  3                1              50            47                pie
# 9590  4                1              25            21                pie
# 9591  3                1              75            34                pie
# 9592  6                2              50            56                pie
# 9593  5                2              50            45                pie
# 9594  6                2              25            31                pie
# 9595  6                1              100           43                pie
# 9596  8                2              0              8                pie
# 9597  9                1              75            15                pie
# 9598  6                2              50            44                pie
# 9599  6                0              100           39                pie
# 9600  5                0              75            15                pie
#      UID ⋯ E  F  G  A_ind B_ind C_ind D_ind E_ind F_ind G_ind
# 1    1   ⋯ 19  7  9 3     6     0     1     2     4     5
# 2    1   ⋯ 11 13 50 4     3     2     1     0     5     6
# 3    1   ⋯  9  3 21 0     2     1     6     4     5     3
# 4    1   ⋯  3 19  4 0     1     4     5     6     3     2
# 5    1   ⋯ 14 11  7 4     5     3     1     2     6     0
# 6    1   ⋯  8  4  3 5     1     2     6     0     3     4
# 7    1   ⋯ 24  7  4 0     6     1     2     5     3     4
# 8    1   ⋯ 10  8  9 6     4     1     3     2     0     5
# 9    1   ⋯ 25 18 19 2     3     6     1     4     5     0
# 10   1   ⋯  7 25 12 1     4     0     6     5     2     3
# 11   1   ⋯  9 12 11 4     6     3     5     2     0     1
# 12   1   ⋯  7 25 10 2     6     0     4     3     1     5
# 13   1   ⋯  8 16 23 4     0     6     5     1     2     3
# 14   1   ⋯  3 20 10 4     3     0     6     1     2     5
# 15   1   ⋯  6 46  3 3     2     5     1     6     0     4
# 16   1   ⋯ 19 22 11 6     5     3     4     1     0     2
# 17   1   ⋯  6 48 10 4     0     2     5     1     3     6
# 18   1   ⋯  7 21 21 5     4     3     1     6     0     2
# 19   1   ⋯ 14 12 21 3     6     4     0     1     5     2
# 20   1   ⋯ 11 18 10 1     3     2     0     5     4     6
# 21   1   ⋯ 18 48 10 0     1     4     2     5     3     6
# 22   1   ⋯ 10 46 14 5     0     6     3     2     1     4
# 23   1   ⋯  6  3 22 5     3     4     0     6     2     1
# 24   1   ⋯  5 22  9 1     2     0     4     3     5     6
# 25   1   ⋯ 12 14 14 6     1     5     3     2     4     0
# 26   1   ⋯  7  1 11 4     2     3     6     1     5     0
# 27   1   ⋯  7 13  6 6     5     4     1     2     3     0
# 28   1   ⋯ 12  3  9 4     0     2     6     5     1     3
# 29   1   ⋯ 18 28 10 1     4     3     2     5     0     6
# 30   1   ⋯ 13  3  7 6     5     1     3     0     2     4
# ⋮    ⋮   ⋱ ⋮  ⋮  ⋮  ⋮     ⋮     ⋮     ⋮     ⋮     ⋮     ⋮
# 9571 100 ⋯ 54  9  6 3     0     1     2     4     6     5
# 9572 100 ⋯ 12 11  1 5     6     3     1     2     0     4
# 9573 100 ⋯ 20 10 10 2     0     6     4     3     5     1
# 9574 100 ⋯  3 10 13 4     0     2     5     3     6     1
# 9575 100 ⋯  8 12 14 4     1     6     3     2     5     0
# 9576 100 ⋯  9 10 18 4     1     6     2     0     3     5
# 9577 100 ⋯ 10  8 11 2     0     3     6     5     1     4
# 9578 100 ⋯  9 11  7 3     6     2     1     5     0     4
# 9579 100 ⋯ 35  4 11 4     0     3     1     2     5     6
# 9580 100 ⋯ 11 18  7 6     1     4     3     5     2     0
# 9581 100 ⋯  8 16 14 1     0     6     5     2     4     3
# 9582 100 ⋯  5 37  5 5     3     6     1     2     0     4
# 9583 100 ⋯  7 10 13 1     4     5     6     0     2     3
# 9584 100 ⋯ 20 37 14 3     4     6     1     0     5     2
# 9585 100 ⋯ 17 14 11 1     3     2     6     4     5     0
# 9586 100 ⋯ 10 40 16 0     5     4     3     6     1     2
# 9587 100 ⋯ 20  5 16 5     3     0     1     4     2     6
# 9588 100 ⋯  7  9  9 4     3     5     0     2     1     6
# 9589 100 ⋯  8  7  9 0     3     2     4     6     1     5
# 9590 100 ⋯  4 19 17 6     4     5     3     1     2     0
# 9591 100 ⋯  8 20 11 0     4     5     1     3     6     2
# 9592 100 ⋯  7 37 10 6     4     1     3     0     5     2
# 9593 100 ⋯ 15 37  6 5     6     1     2     0     4     3
# 9594 100 ⋯ 12  9  8 4     5     2     6     3     0     1
# 9595 100 ⋯  5  3 51 0     4     3     6     2     1     5
# 9596 100 ⋯ 10  7  4 0     6     1     4     5     2     3
# 9597 100 ⋯ 51  3 11 6     1     4     3     2     5     0
# 9598 100 ⋯ 43  5 13 3     2     0     1     5     4     6
# 9599 100 ⋯  8  8  6 2     4     3     5     1     0     6
# 9600 100 ⋯  9  8  8 1     6     2     4     5     0     3

# %%
# # Make sure A to G are numeric
# part_cols <- LETTERS[1:7]

# stimuli[part_cols] <- lapply(stimuli[part_cols], as.numeric)

# # Now compute row sums safely
# stimuli$partSum <- rowSums(stimuli[part_cols])

# # Count how many do not sum to 100
# sum(stimuli$partSum != 100)

# %%
# Step 1: Get part value columns and their index columns
part_cols <- LETTERS[1:7]             # A to G
index_cols <- paste0(part_cols, "_ind")  # A_ind to G_ind

# Step 2: Define a function to get pre-selected part sum and compare to alignmentPosition
check_alignment <- function(row) {
  selected_label <- row["selectedLabel"]
  selected_index <- as.numeric(row[paste0(selected_label, "_ind")])
  alignment_pos <- as.numeric(row["alignmentPosition"])
  
  # Extract all part indices from the row
  part_indices <- as.numeric(row[index_cols])
  part_values <- as.numeric(row[part_cols])
  
  # Find parts that are before the selected part index
  preceding_values <- part_values[part_indices < selected_index]
  
  # Return the sum of preceding values (should equal alignmentPosition)
  sum(preceding_values) == alignment_pos
}

# Step 3: Apply the check across all rows
alignment_correct <- apply(stimuli, 1, check_alignment)

# Step 4: Count how many rows fail the check
sum(!alignment_correct)
# Out:
# [1] 0

# %%
sum(stimuli$selectedPart != mapply(function(label, row) stimuli[row, label], 
                                        stimuli$selectedLabel, 
                                        seq_len(nrow(stimuli))))
# Out:
# [1] 0

# %%
library(dplyr)

stimuli <- stimuli %>%
  group_by(UID) %>%
  slice_sample(prop = 1) %>%
  ungroup()

# %%
stimuli
# Out:
#      selectedPart alignmentCategory anchorCategory anchorDistance
# 1    40           aligned           far-anchor     10
# 2    22           aligned           near-anchor     3
# 3    22           aligned           near-anchor     3
# 4    50           aligned           anchor          0
# 5    25           far-from-aligned  anchor          0
# 6    16           near-aligned      far-anchor      9
# 7    17           aligned           far-anchor      8
# 8    52           near-aligned      far-anchor      2
# 9    20           aligned           far-anchor      5
# 10   22           far-from-aligned  near-anchor     3
# 11   34           far-from-aligned  far-anchor      9
# 12   18           aligned           far-anchor      7
# 13   17           near-aligned      far-anchor      8
# 14   53           near-aligned      far-anchor      3
# 15   31           far-from-aligned  far-anchor      6
# 16   15           far-from-aligned  far-anchor     10
# 17   25           near-aligned      anchor          0
# 18   18           far-from-aligned  far-anchor      7
# 19   23           near-aligned      near-anchor     2
# 20   53           far-from-aligned  far-anchor      3
# 21   48           aligned           near-anchor     2
# 22   32           far-from-aligned  far-anchor      7
# 23   25           far-from-aligned  anchor          0
# 24   41           near-aligned      far-anchor      9
# 25   46           near-aligned      near-anchor     4
# 26   31           aligned           far-anchor      6
# 27   50           far-from-aligned  anchor          0
# 28   48           aligned           near-anchor     2
# 29   19           aligned           far-anchor      6
# 30   16           aligned           far-anchor      9
# ⋮    ⋮            ⋮                 ⋮              ⋮
# 9571 28           near-aligned      near-anchor     3
# 9572 22           near-aligned      near-anchor     3
# 9573 44           near-aligned      far-anchor      6
# 9574 48           far-from-aligned  near-anchor     2
# 9575 31           far-from-aligned  far-anchor      6
# 9576 36           aligned           far-anchor     11
# 9577 54           near-aligned      far-anchor      4
# 9578 53           far-from-aligned  far-anchor      3
# 9579 40           near-aligned      far-anchor     10
# 9580 18           aligned           far-anchor      7
# 9581 52           far-from-aligned  far-anchor      2
# 9582 48           aligned           near-anchor     2
# 9583 27           aligned           near-anchor     2
# 9584 48           near-aligned      near-anchor     2
# 9585 51           far-from-aligned  far-anchor      1
# 9586 53           far-from-aligned  far-anchor      3
# 9587 31           far-from-aligned  far-anchor      6
# 9588 37           aligned           far-anchor     12
# 9589 26           far-from-aligned  near-anchor     1
# 9590 27           aligned           near-anchor     2
# 9591 19           near-aligned      far-anchor      6
# 9592 26           far-from-aligned  near-anchor     1
# 9593 40           near-aligned      far-anchor     10
# 9594 31           near-aligned      far-anchor      6
# 9595 36           near-aligned      far-anchor     11
# 9596 31           aligned           far-anchor      6
# 9597 23           near-aligned      near-anchor     2
# 9598 29           far-from-aligned  near-anchor     4
# 9599 35           aligned           far-anchor     10
# 9600 49           far-from-aligned  near-anchor     1
#      alignmentDistance round5Distance alignmentType alignmentPosition chartType
# 1     0                0              75            35                pie
# 2     0                2              0              0                line
# 3     0                2              0              0                pie
# 4     0                0              50 and 100    50                line
# 5     7                0              25 and 50     18                pie
# 6     1                1              100           83                pie
# 7     0                2              50            50                line
# 8     3                2              25            28                line
# 9     0                0              0              0                line
# 10    5                2              75            58                pie
# 11    6                1              100           60                line
# 12    0                2              75            57                pie
# 13    1                2              50            49                pie
# 14    3                2              0              3                line
# 15    6                1              50            56                pie
# 16    6                0              50            44                line
# 17    2                0              50 and 75     48                pie
# 18    7                2              25            18                pie
# 19    3                2              50            47                pie
# 20   10                2              75            12                line
# 21    0                2              0              0                line
# 22    7                2              75            36                pie
# 23    7                0              0 and 25       7                line
# 24    4                1              100           55                pie
# 25    1                1              50             3                line
# 26    0                1              100           69                line
# 27   11                0              25 and 75     14                line
# 28    0                2              75            27                line
# 29    0                1              75            56                line
# 30    0                1              100           84                line
# ⋮    ⋮                 ⋮              ⋮             ⋮                 ⋮
# 9571  4                2              75            43                line
# 9572  4                2              25             7                line
# 9573  3                1              75            34                pie
# 9574 11                2              25            14                pie
# 9575  6                1              50            13                line
# 9576  0                1              100           64                pie
# 9577  1                1              100           45                line
# 9578 10                2              100           37                line
# 9579  1                0              50             9                line
# 9580  0                2              50            32                pie
# 9581 11                2              0             11                line
# 9582  0                2              75            27                pie
# 9583  0                2              25            25                pie
# 9584  2                2              25            23                pie
# 9585  6                1              100           43                pie
# 9586  8                2              0              8                pie
# 9587  8                1              25            33                line
# 9588  0                2              0              0                pie
# 9589  9                1              50            15                pie
# 9590  0                2              25            25                line
# 9591  4                1              25            21                pie
# 9592  7                1              0              7                line
# 9593  3                0              50             7                pie
# 9594  3                1              50            53                pie
# 9595  3                1              50            47                pie
# 9596  0                1              50            50                line
# 9597  3                2              50            30                pie
# 9598  5                1              50            55                line
# 9599  0                0              25            25                pie
# 9600  5                1              25            20                line
#      UID ⋯ E  F  G  A_ind B_ind C_ind D_ind E_ind F_ind G_ind
# 1    1   ⋯  9 16 40 5     1     2     6     3     0     4
# 2    1   ⋯ 19 22 11 6     5     3     4     1     0     2
# 3    1   ⋯ 15  9 14 4     1     0     5     2     6     3
# 4    1   ⋯ 19  7  9 3     6     0     1     2     4     5
# 5    1   ⋯  7 25 10 2     6     0     4     3     1     5
# 6    1   ⋯  1 32 12 5     0     2     1     6     4     3
# 7    1   ⋯ 13 14  2 5     4     6     1     0     2     3
# 8    1   ⋯  3  9 11 0     1     4     5     3     6     2
# 9    1   ⋯ 22 19 22 2     6     0     4     5     3     1
# 10   1   ⋯ 20  9  3 4     1     6     5     2     3     0
# 11   1   ⋯  3 10 18 2     3     6     5     1     4     0
# 12   1   ⋯ 11 18  6 5     1     6     2     3     4     0
# 13   1   ⋯  1 17 16 6     3     1     4     2     0     5
# 14   1   ⋯  6 12  7 1     5     6     0     3     4     2
# 15   1   ⋯  4 14 25 6     1     2     5     4     3     0
# 16   1   ⋯ 22 12 12 0     4     3     5     6     2     1
# 17   1   ⋯ 25 18 19 2     3     6     1     4     5     0
# 18   1   ⋯  3 20 11 0     3     1     6     4     5     2
# 19   1   ⋯ 15  4 15 2     4     6     5     0     3     1
# 20   1   ⋯  6 53  1 5     1     4     3     6     2     0
# 21   1   ⋯  3 20 10 4     3     0     6     1     2     5
# 22   1   ⋯  7 12 16 3     6     4     1     5     0     2
# 23   1   ⋯ 14 11  7 4     5     3     1     2     6     0
# 24   1   ⋯ 10 15  4 5     4     3     1     2     0     6
# 25   1   ⋯ 10 46 14 5     0     6     3     2     1     4
# 26   1   ⋯ 17  6 12 5     0     6     3     2     4     1
# 27   1   ⋯  8  4  3 5     1     2     6     0     3     4
# 28   1   ⋯  6 48 10 4     0     2     5     1     3     6
# 29   1   ⋯  7 20 20 6     4     3     1     5     0     2
# 30   1   ⋯ 39  9  9 6     5     0     4     1     2     3
# ⋮    ⋮   ⋱ ⋮  ⋮  ⋮  ⋮     ⋮     ⋮     ⋮     ⋮     ⋮     ⋮
# 9571 100 ⋯  6 24  5 0     4     5     6     2     1     3
# 9572 100 ⋯  7  7 12 1     2     3     4     5     0     6
# 9573 100 ⋯  8 20 11 0     4     5     1     3     6     2
# 9574 100 ⋯  6  8  7 5     4     6     2     1     0     3
# 9575 100 ⋯ 10 31  2 5     2     6     0     3     1     4
# 9576 100 ⋯  9 11  7 3     6     2     1     5     0     4
# 9577 100 ⋯  2 54  1 4     2     0     3     1     5     6
# 9578 100 ⋯  3 10 13 4     0     2     5     3     6     1
# 9579 100 ⋯  2 28  7 1     5     0     6     2     3     4
# 9580 100 ⋯ 11 18  7 6     1     4     3     5     2     0
# 9581 100 ⋯ 12 11  1 5     6     3     1     2     0     4
# 9582 100 ⋯  6 48  5 1     6     5     0     2     3     4
# 9583 100 ⋯ 27  9 13 3     1     5     6     2     4     0
# 9584 100 ⋯  4 48 11 6     2     4     1     5     3     0
# 9585 100 ⋯  5  3 51 0     4     3     6     2     1     5
# 9586 100 ⋯ 10  7  4 0     6     1     4     5     2     3
# 9587 100 ⋯  6  5 12 5     0     3     6     2     4     1
# 9588 100 ⋯  5 37  5 5     3     6     1     2     0     4
# 9589 100 ⋯ 18  6 11 6     5     0     1     2     3     4
# 9590 100 ⋯ 15 20 10 2     6     4     3     1     5     0
# 9591 100 ⋯  4 19 17 6     4     5     3     1     2     0
# 9592 100 ⋯ 26  6  7 3     4     5     2     1     6     0
# 9593 100 ⋯ 10 40 16 0     5     4     3     6     1     2
# 9594 100 ⋯ 20  5 16 5     3     0     1     4     2     6
# 9595 100 ⋯  8  7  9 0     3     2     4     6     1     5
# 9596 100 ⋯ 31 13 13 1     0     3     5     4     2     6
# 9597 100 ⋯ 15 15 23 4     6     5     3     0     1     2
# 9598 100 ⋯ 13  3 19 6     0     5     1     4     3     2
# 9599 100 ⋯ 35  4 11 4     0     3     1     2     5     6
# 9600 100 ⋯ 19  5  7 2     6     0     5     4     1     3

# %%
write.csv(stimuli, "data/stimuli.csv", row.names = FALSE)
